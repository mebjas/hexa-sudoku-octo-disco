# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('../dataset/1.jpg', 0)

# %%
plt.figure(figsize=(15, 10))
plt.imshow(img, cmap = 'gray')

# %%
plt.figure(figsize=(15, 10))
edges = cv2.Canny(img, 200, 500)
# plt.imshow(edges,cmap = 'gray')
plt.imshow(edges)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-23-2aa019df15e3> in <module>
# ----> 1 gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       2 ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
#
# error: /build/opencv-pUeNCp/opencv-3.2.0+dfsg/modules/imgproc/src/color.cpp:9748: error: (-215) scn == 3 || scn == 4 in function cvtColor

# %%
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imgray, 127, 255, 0)
image, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-816b890383e0> in <module>
# ----> 1 imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       2 ret, thresh = cv2.threshold(imgray, 127, 255, 0)
#       3 image, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#
# error: /build/opencv-pUeNCp/opencv-3.2.0+dfsg/modules/imgproc/src/color.cpp:9748: error: (-215) scn == 3 || scn == 4 in function cvtColor

# %%
plt.imshow(img, cmap = 'gray')
ret, thresh = cv2.threshold(img, 127, 255, 0)
image, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
plt.imshow(image, cmap = 'gray')
